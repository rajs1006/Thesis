# %% [markdown]
# # 6 DoF Pose from Semantic Keypoints #
#
# The following is an implementation of https://www.seas.upenn.edu/~pavlakos/projects/object3d/
# Find the associated tutorial at:https://medium.com/@vaishakvk/geometric-deep-learning-for-pose-estimation-6af45da05922
#
# This is an adaptation of code used in Prof.Kostas Daniilidis' course.

# %%
from __future__ import division
from __future__ import print_function

import torch
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torchvision import transforms
from torchvision.utils import make_grid
import pandas as pd
import imageio
import matplotlib.pyplot as plt
from tqdm import tqdm
from PIL import Image
import os
#from os import join
from time import time
import numpy as np
import cv2 

# %run Utils.ipynb
# %run Visualize.ipynb
# %run Model.ipynb

os.makedirs('./output', exist_ok=True)

path = "/home/sourabh/Documents/TU-Berlin/Thesis/Sytheticdata"

# %% [markdown]
# ## Keypoint Localization ##
#
# First, we will create the dataset class and a few transformations

# %%
crop = CropAndPad(out_size=(256, 256))

transform_list = [CropAndPad(out_size=(256, 256))]
composed = transforms.Compose(transform_list)

# apply the transforms to a sample image
dataSet = Dataset(transform=None, length=6)


fig = plt.figure()
for i, tx in enumerate([crop, composed]):
    transformed_sample = tx(dataSet[1].copy())

    ax = plt.subplot(1, 3, i + 1)
    plt.tight_layout()
    ax.set_title(type(tx).__name__)
    show_keypoints(transformed_sample['image'], transformed_sample['keypoints'])

    plt.show()

# %%
# trainer = Trainer()
# trainer.train(epoch=1)

# %%
tester = Tester(root_dir = 'ml-imagesynthesis/data', batch_size = 1)
centers, crops, scales = tester.test()
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.76s/it]

# %% [markdown]
# ## Detected Keypoint Visualizations##

# %%
detectedHMs = torch.from_numpy(np.load('./output/detections.npy'))
detectedKPs = heatmaps_to_locs(detectedHMs)

KPs = detectedKPs[:,:,:-1] * (256 / 64)
KPs = KPs / scales[:,None,:]
KPs = KPs + crops[:,None,:]

test_ds = Dataset(root_dir = 'ml-imagesynthesis/data', folder="Test/", transform=None, length=5)

visualize_output(test_ds, KPs, gt_pts=True, plot=True ,batch_size=2, savefig=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-99899410886c> in <module>
#       8 test_ds = Dataset(root_dir = 'ml-imagesynthesis/data', folder="Test/", transform=None, length=5)
#       9
# ---> 10 visualize_output(test_ds, KPs, gt_pts=True, plot=True ,batch_size=2, savefig=True)
#
# <ipython-input-5-e3078e198fff> in visualize_output(data, test_outputs, gt_pts, batch_size, plot, savefig)
#      36
#      37         # un-transform the predicted key_pts data
# ---> 38         predicted_key_pts = test_outputs[i].data
#      39         predicted_key_pts = predicted_key_pts.numpy()
#      40
#
# IndexError: index 1 is out of bounds for dimension 0 with size 1

# %%
oori_images,test_images, test_outputs, gt_pts = Tester(batch_size = 10).test_net()

##print out the dimensions of the data to see if they make sense
print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())

visualize_test_output(test_images, test_outputs, gt_pts, plot=True ,batch_size=10)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([10, 3, 256, 256])
# torch.Size([10, 18, 2])
# torch.Size([10, 18, 2])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...
